# %% [markdown]
# **Context**
# This classic dataset contains the prices and other attributes of almost 54,000 diamonds. It's a great dataset for beginners learning to work with data analysis and visualization.
#
# **Content**
# price price in US dollars ( USD 326 -- USD 18,823)
#
# carat weight of the diamond (0.2--5.01)
#
# cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# color diamond colour, from J (worst) to D (best)
#
# clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# x length in mm (0--10.74)
#
# y width in mm (0--58.9)
#
# z depth in mm (0--31.8)
#
# depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# table width of top of diamond relative to widest point (43--95)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arqPath = "diamonds.csv"
data = pd.read_csv(arqPath, index_col = 0)

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data['volume'] = data['x'] * data['y'] * data['z']

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#            volume
# 1       38.202030
# 2       34.505856
# 3       38.076885
# 4       46.724580
# 5       51.917250
# ...           ...
# 53936  115.920000
# 53937  118.110175
# 53938  114.449728
# 53939  140.766120
# 53940  124.568444
#
# [53940 rows x 11 columns]

# %% [markdown]
# **This is a block of text!**

# %%
dataSorted = data.sort_values('price')
dataSorted = dataSorted.reset_index()
dataSorted
# Out:
#        index  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00
# 53936  27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13
# 53937  27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41
# 53938  27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97
# 53939  27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47
#
#           z      volume
# 0      2.43   38.202030
# 1      2.31   34.505856
# 2      2.31   38.076885
# 3      2.63   46.724580
# 4      2.75   51.917250
# ...     ...         ...
# 53935  5.01  318.636000
# 53936  5.11  340.663260
# 53937  4.56  249.029352
# 53938  5.04  317.333520
# 53939  5.16  371.494200
#
# [53940 rows x 12 columns]

# %%
dataSorted.tail(1)
# Out:
#        index  carat      cut color clarity  depth  table  price    x     y  \
# 53939  27750   2.29  Premium     I     VS2   60.8   60.0  18823  8.5  8.47
#
#           z    volume
# 53939  5.16  371.4942

# %%
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.30      Ideal     G      IF   60.9   57.0    956  4.32  4.29  2.62
# 1       0.38      Ideal     D    VVS2   61.5   56.0   1200  4.64  4.66  2.86
# 2       1.50       Good     I     SI1   64.0   60.0   8736  7.25  7.13  4.60
# 3       1.19      Ideal     J     SI1   62.0   56.0   4678  6.80  6.77  4.21
# 4       1.50      Ideal     F     VS2   61.4   55.0  14372  7.44  7.35  4.54
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.90  Very Good     F     VS2   63.1   59.0   4627  6.13  6.05  3.84
# 53936   1.03  Very Good     H     SI1   61.4   57.0   4879  6.45  6.54  3.99
# 53937   1.20  Very Good     G     SI1   63.5   56.0   6666  6.77  6.70  4.28
# 53938   1.08      Ideal     F     SI1   62.9   57.0   5106  6.54  6.53  4.11
# 53939   0.43      Ideal     G      IF   61.7   57.0   1286  4.83  4.86  2.99
#
#            volume
# 0       48.555936
# 1       61.840064
# 2      237.785500
# 3      193.811560
# 4      248.265360
# ...           ...
# 53935  142.412160
# 53936  168.310170
# 53937  194.136520
# 53938  175.522482
# 53939   70.186662
#
# [53940 rows x 11 columns]

# %%
import itertools
plt.scatter(data['carat'], data['price'], c=list(data['volume']))
##plt.viridis()

# %%
data['color']
# Out:
# 0        G
# 1        D
# 2        I
# 3        J
# 4        F
#         ..
# 53935    F
# 53936    H
# 53937    G
# 53938    F
# 53939    G
# Name: color, Length: 53940, dtype: object

# %%
## color diamond colour, from J (worst) to D (best)
colorsDict = {'J':1, 'I':2, 'H':3, 'G':4, 'F':5, 'E':6, 'D':7}
colorsDict
# Out:
# {'J': 1, 'I': 2, 'H': 3, 'G': 4, 'F': 5, 'E': 6, 'D': 7}

# %%
## cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
cutDict =  {'Fair':1, 'Good':2, 'Very Good':3, 'Premium':4, 'Ideal':5}
cutDict
# Out:
# {'Fair': 1, 'Good': 2, 'Very Good': 3, 'Premium': 4, 'Ideal': 5}

# %%
## clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
clarityDict = {'I1':1, 'SI2':2, 'SI1':3, 'VS2':4, 'VS1':5, 'VVS2':6, 'VVS1':7, 'IF':8}
clarityDict
# Out:
# {'I1': 1,
#  'SI2': 2,
#  'SI1': 3,
#  'VS2': 4,
#  'VS1': 5,
#  'VVS2': 6,
#  'VVS1': 7,
#  'IF': 8}

# %%
color = [colorsDict[i] for i in data['color']]
cut = [cutDict[i] for i in data['cut']]
clarity = [clarityDict[i] for i in data['clarity']]

# %%
data['cut'] = cut
data['color'] = color
data['clarity'] = clarity

# %%
plt.scatter(data['carat'], data['price'], c=color, cmap='viridis')
plt.show()

# %%
plt.scatter(data['carat'], data['price'], c=cut, cmap='viridis')
plt.show()

# %%
plt.scatter(data['carat'], data['price'], c=clarity, cmap='viridis')
plt.show()

# %%
plt.scatter(data['carat'], data['price'], c=data['table'], cmap='viridis')
plt.show()

# %%
plt.scatter(data['carat'], data['price'], c=data['depth'], cmap='viridis')
plt.show()

# %%
data['table']
# Out:
# 0        57.0
# 1        56.0
# 2        60.0
# 3        56.0
# 4        55.0
#          ...
# 53935    59.0
# 53936    57.0
# 53937    56.0
# 53938    57.0
# 53939    57.0
# Name: table, Length: 53940, dtype: float64

# %%
(data['table']).mean()
# Out:
# 57.45718390804598

# %%
(data['table']).std()
# Out:
# 2.2344905628213225

# %%
data.mean()
# Out:
# carat         0.797940
# cut           3.904097
# color         4.405803
# clarity       4.051020
# depth        61.749405
# table        57.457184
# price      3932.799722
# x             5.731157
# y             5.734526
# z             3.538734
# volume      129.849403
# dtype: float64

# %%
data.std()
# Out:
# carat         0.474011
# cut           1.116600
# color         1.701105
# clarity       1.647136
# depth         1.432621
# table         2.234491
# price      3989.439738
# x             1.121761
# y             1.142135
# z             0.705699
# volume       78.245262
# dtype: float64

# %%
data.max()
# Out:
# carat          5.01000
# cut            5.00000
# color          7.00000
# clarity        8.00000
# depth         79.00000
# table         95.00000
# price      18823.00000
# x             10.74000
# y             58.90000
# z             31.80000
# volume      3840.59806
# dtype: float64

# %%
data.min()
# Out:
# carat        0.2
# cut          1.0
# color        1.0
# clarity      1.0
# depth       43.0
# table       43.0
# price      326.0
# x            0.0
# y            0.0
# z            0.0
# volume       0.0
# dtype: float64

# %%
plt.scatter(data['carat'], data['price'], c=data['x'], cmap='viridis')
plt.show()

# %%
plt.scatter(data['carat'], data['price'], c=data['y'], cmap='viridis')
plt.show()

# %%
plt.scatter(data['carat'], data['price'], c=data['z'], cmap='viridis')
plt.show()

# %%
plt.scatter(data['carat'], data['price'], c=data['volume'], cmap='viridis')
plt.show()

# %%
plt.hist(data['price'], bins=100)
plt.show()

# %%
plt.hist(data['carat'], bins=100, range=(0,3))
plt.show()

# %%
sns.kdeplot(data['carat'], shade=True)

# %%
plt.hist(data['table'], bins=100, range=(50,70))
plt.show()

# %%
plt.hist(data['x'], bins=100, range=(3,10))
plt.show()

# %%
plt.hist(data['y'], bins=100, range=(3,9))
plt.show()

# %%
plt.hist(data['z'], bins=100, range=(2,6))
plt.show()

# %%
plt.scatter(data['table'], data['depth'], c=data['price'], cmap='viridis')
plt.show()

# %%
sns.catplot(data=data , kind='box' , height=10, aspect=2.5)

# %%
sns.catplot(x='cut', y='price', data=data, kind='box' ,aspect=2.5 )

# %%
sns.catplot(x='color', y='price', data=data, kind='box' ,aspect=2.5 )

# %%
sns.catplot(x='clarity', y='price', data=data, kind='box' ,aspect=2.5 )

# %%
sns.catplot(x='cut', y='price' , data=data , kind='violin', aspect=2.5)

# %%
sns.catplot(x='color', y='price' , data=data , kind='violin', aspect=2.5)

# %%
sns.catplot(x='clarity', y='price' , data=data , kind='violin', aspect=2.5)

# %%
sns.kdeplot(data['x'] ,shade=True , color='r' )
sns.kdeplot(data['y'] , shade=True , color='g' )
sns.kdeplot(data['z'] , shade= True , color='b')
plt.xlim(2,10)
# Out:
# (2, 10)

# %%
sns.jointplot(x='volume', y='price' , data=data, height=8)

# %%
plt.scatter(data['table'], data['price'], c=color, cmap='viridis')
plt.show()

# %%
plt.scatter(data['depth'], data['price'], c=color, cmap='viridis')

# %%
pairplot = sns.pairplot(data)

# %%
# Podemos ver que há 2 pontos outliers. Por inspeção, são os pontos com y > 20. Vamos removê-los.

# %%
data.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940      3.904097      4.405803      4.051020     61.749405
# std        0.474011      1.116600      1.701105      1.647136      1.432621
# min        0.200000      1.000000      1.000000      1.000000     43.000000
# 25%        0.400000      3.000000      3.000000      3.000000     61.000000
# 50%        0.700000      4.000000      4.000000      4.000000     61.800000
# 75%        1.040000      5.000000      6.000000      5.000000     62.500000
# max        5.010000      5.000000      7.000000      8.000000     79.000000
#
#               table         price             x             y             z  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      57.457184   3932.799722      5.731157      5.734526      3.538734
# std        2.234491   3989.439738      1.121761      1.142135      0.705699
# min       43.000000    326.000000      0.000000      0.000000      0.000000
# 25%       56.000000    950.000000      4.710000      4.720000      2.910000
# 50%       57.000000   2401.000000      5.700000      5.710000      3.530000
# 75%       59.000000   5324.250000      6.540000      6.540000      4.040000
# max       95.000000  18823.000000     10.740000     58.900000     31.800000
#
#              volume
# count  53940.000000
# mean     129.849403
# std       78.245262
# min        0.000000
# 25%       65.136830
# 50%      114.808572
# 75%      170.842451
# max     3840.598060

# %%
hist = data.hist(figsize = (25,25), bins=100)

# %%
## Visualizando entradas com dimensão 'zero'

data.loc[(data['x']==0) | (data['y']==0) | (data['z']==0)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z, volume]
# Index: []

# %%
# Quantos têm dimensão zero?
len(data.loc[(data['volume']==0)])
# Out:
# 20

# %%
data = data[(data[['x','y','z']] != 0).all(axis=1)]

# %%
# Confirmando

data.loc[(data['x']==0) | (data['y']==0) | (data['z']==0)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z, volume]
# Index: []

# %%
data.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698      3.904228      4.405972      4.051502     61.749514
# std        0.473795      1.116579      1.701272      1.647005      1.432331
# min        0.200000      1.000000      1.000000      1.000000     43.000000
# 25%        0.400000      3.000000      3.000000      3.000000     61.000000
# 50%        0.700000      4.000000      4.000000      4.000000     61.800000
# 75%        1.040000      5.000000      6.000000      5.000000     62.500000
# max        5.010000      5.000000      7.000000      8.000000     79.000000
#
#               table         price             x             y             z  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean      57.456834   3930.993231      5.731627      5.734887      3.540046
# std        2.234064   3987.280446      1.119423      1.140126      0.702530
# min       43.000000    326.000000      3.730000      3.680000      1.070000
# 25%       56.000000    949.000000      4.710000      4.720000      2.910000
# 50%       57.000000   2401.000000      5.700000      5.710000      3.530000
# 75%       59.000000   5323.250000      6.540000      6.540000      4.040000
# max       95.000000  18823.000000     10.740000     58.900000     31.800000
#
#              volume
# count  53920.000000
# mean     129.897567
# std       78.219789
# min       31.707984
# 25%       65.189759
# 50%      114.840180
# 75%      170.846415
# max     3840.598060

# %%
# Visualizando outliers y>20 e z>20

# %%
data.loc[(data['y']>20)]
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z  \
# 29112   0.51    5      6        5   61.8   55.0   2075  5.15  31.8  5.12
# 32664   2.00    4      3        2   58.9   57.0  12210  8.09  58.9  8.06
#
#            volume
# 29112   838.50240
# 32664  3840.59806

# %%
data = data[(data[['y']] < 20).all(axis=1)]

# %%
data.loc[(data['y']>20)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z, volume]
# Index: []

# %%
data.loc[(data['z']>20)]
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z  \
# 17595   0.51    3      6        5   61.8   54.7   1970  5.12  5.15  31.8
#
#          volume
# 17595  838.5024

# %%
data = data[(data[['z']] < 20).all(axis=1)]

# %%
data.loc[(data['z']>20)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z, volume]
# Index: []

# %%
data.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  53917.000000  53917.000000  53917.000000  53917.000000  53917.000000
# mean       0.797687      3.904223      4.405939      4.051505     61.749565
# std        0.473777      1.116593      1.701281      1.647017      1.432318
# min        0.200000      1.000000      1.000000      1.000000     43.000000
# 25%        0.400000      3.000000      3.000000      3.000000     61.000000
# 50%        0.700000      4.000000      4.000000      4.000000     61.800000
# 75%        1.040000      5.000000      6.000000      5.000000     62.500000
# max        5.010000      5.000000      7.000000      8.000000     79.000000
#
#               table         price             x             y             z  \
# count  53917.000000  53917.000000  53917.000000  53917.000000  53917.000000
# mean      57.456939   3930.910474      5.731605      5.733428      3.539409
# std        2.234069   3987.215003      1.119402      1.111272      0.691620
# min       43.000000    326.000000      3.730000      3.680000      1.070000
# 25%       56.000000    949.000000      4.710000      4.720000      2.910000
# 50%       57.000000   2401.000000      5.700000      5.710000      3.530000
# 75%       59.000000   5323.000000      6.540000      6.540000      4.040000
# max       95.000000  18823.000000     10.740000     10.540000      6.980000
#
#              volume
# count  53917.000000
# mean     129.802460
# std       76.450353
# min       31.707984
# 25%       65.188530
# 50%      114.840180
# 75%      170.844704
# max      790.133208

# %%
hist = data.hist(figsize = (25,25), bins=100)

# %%
pairplot = sns.pairplot(data)

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,10

heatmap = sns.heatmap(data.corr(), linewidth=0, annot=True, center=0.5, cmap='Blues')

# %%
dataClean = data.drop(['x', 'y', 'z'], axis=1)
dataClean
# Out:
#        carat  cut  color  clarity  depth  table  price      volume
# 0       0.30    5      4        8   60.9   57.0    956   48.555936
# 1       0.38    5      7        6   61.5   56.0   1200   61.840064
# 2       1.50    2      2        3   64.0   60.0   8736  237.785500
# 3       1.19    5      1        3   62.0   56.0   4678  193.811560
# 4       1.50    5      5        4   61.4   55.0  14372  248.265360
# ...      ...  ...    ...      ...    ...    ...    ...         ...
# 53935   0.90    3      5        4   63.1   59.0   4627  142.412160
# 53936   1.03    3      3        3   61.4   57.0   4879  168.310170
# 53937   1.20    3      4        3   63.5   56.0   6666  194.136520
# 53938   1.08    5      5        3   62.9   57.0   5106  175.522482
# 53939   0.43    5      4        8   61.7   57.0   1286   70.186662
#
# [53920 rows x 8 columns]

# %%
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z  \
# 0       0.29    3      4        4   62.0   55.0    471  4.24  4.27  2.63
# 1       0.40    3      6        3   61.7   60.0    687  4.68  4.72  2.90
# 2       1.16    5      7        3   62.0   56.0   5911  6.76  6.73  4.18
# 3       0.41    2      7        4   63.4   54.0    873  4.74  4.79  3.02
# 4       0.36    3      2        6   59.7   55.0    571  4.65  4.69  2.79
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53915   0.30    3      7        2   61.4   59.0    447  4.26  4.31  2.63
# 53916   0.43    4      4        7   60.3   58.0   1264  4.91  4.87  2.95
# 53917   0.52    5      5        6   62.0   55.0   2168  5.16  5.20  3.21
# 53918   0.81    4      4        4   62.0   58.0   2994  5.95  5.92  3.68
# 53919   0.70    2      3        3   65.4   59.0   1840  5.46  5.52  3.59
#
#            volume
# 0       47.615624
# 1       64.059840
# 2      190.168264
# 3       68.567892
# 4       60.845715
# ...           ...
# 53915   48.288378
# 53916   70.539515
# 53917   86.130720
# 53918  129.624320
# 53919  108.199728
#
# [53920 rows x 11 columns]

# %%
y = data['price']
x = data.drop(['price'], axis=1)

# %%
x
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z      volume
# 0       0.29    3      4        4   62.0   55.0  4.24  4.27  2.63   47.615624
# 1       0.40    3      6        3   61.7   60.0  4.68  4.72  2.90   64.059840
# 2       1.16    5      7        3   62.0   56.0  6.76  6.73  4.18  190.168264
# 3       0.41    2      7        4   63.4   54.0  4.74  4.79  3.02   68.567892
# 4       0.36    3      2        6   59.7   55.0  4.65  4.69  2.79   60.845715
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...         ...
# 53915   0.30    3      7        2   61.4   59.0  4.26  4.31  2.63   48.288378
# 53916   0.43    4      4        7   60.3   58.0  4.91  4.87  2.95   70.539515
# 53917   0.52    5      5        6   62.0   55.0  5.16  5.20  3.21   86.130720
# 53918   0.81    4      4        4   62.0   58.0  5.95  5.92  3.68  129.624320
# 53919   0.70    2      3        3   65.4   59.0  5.46  5.52  3.59  108.199728
#
# [53920 rows x 10 columns]

# %%
y
# Out:
# 0         471
# 1         687
# 2        5911
# 3         873
# 4         571
#          ...
# 53915     447
# 53916    1264
# 53917    2168
# 53918    2994
# 53919    1840
# Name: price, Length: 53920, dtype: int64

# %%
#compare = pd.DataFrame({'Algorithms' : models , 'R2-Scores' : R2_Scores})
#compare.sort_values(by='R2-Scores' ,ascending=False)

# %%
#sns.barplot(x='R2-Scores' , y='Algorithms' , data=compare)

# %%
#sns.factorplot(x='Algorithms', y='R2-Scores' , data=compare, size=6 , aspect=4)

# %%
#from sklearn.preprocessing import StandardScaler
#dataScaled =

# %%
data
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z  \
# 0       0.29    3      4        4   62.0   55.0    471  4.24  4.27  2.63
# 1       0.40    3      6        3   61.7   60.0    687  4.68  4.72  2.90
# 2       1.16    5      7        3   62.0   56.0   5911  6.76  6.73  4.18
# 3       0.41    2      7        4   63.4   54.0    873  4.74  4.79  3.02
# 4       0.36    3      2        6   59.7   55.0    571  4.65  4.69  2.79
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53915   0.30    3      7        2   61.4   59.0    447  4.26  4.31  2.63
# 53916   0.43    4      4        7   60.3   58.0   1264  4.91  4.87  2.95
# 53917   0.52    5      5        6   62.0   55.0   2168  5.16  5.20  3.21
# 53918   0.81    4      4        4   62.0   58.0   2994  5.95  5.92  3.68
# 53919   0.70    2      3        3   65.4   59.0   1840  5.46  5.52  3.59
#
#            volume
# 0       47.615624
# 1       64.059840
# 2      190.168264
# 3       68.567892
# 4       60.845715
# ...           ...
# 53915   48.288378
# 53916   70.539515
# 53917   86.130720
# 53918  129.624320
# 53919  108.199728
#
# [53917 rows x 11 columns]

# %%
data.mean()
# Out:
# carat         0.797687
# cut           3.904223
# color         4.405939
# clarity       4.051505
# depth        61.749565
# table        57.456939
# price      3930.910474
# x             5.731605
# y             5.733428
# z             3.539409
# volume      129.802460
# dtype: float64

# %%
data.std()
# Out:
# carat         0.473777
# cut           1.116593
# color         1.701281
# clarity       1.647017
# depth         1.432318
# table         2.234069
# price      3987.215003
# x             1.119402
# y             1.111272
# z             0.691620
# volume       76.450353
# dtype: float64

# %%
dataScaled = (data - data.mean())/data.std()
dataScaled
# Out:
#           carat       cut     color   clarity     depth     table     price  \
# 0     -1.071573 -0.809805 -0.238608 -0.031272  0.174846 -1.099760 -0.867751
# 1     -0.839396 -0.809805  0.936977 -0.638430 -0.034605  1.138309 -0.813578
# 2      0.764734  0.981357  1.524769 -0.638430  0.174846 -0.652146  0.496610
# 3     -0.818289 -1.705387  1.524769 -0.031272  1.152282 -1.547374 -0.766929
# 4     -0.923824 -0.809805 -1.414192  1.183045 -1.430942 -1.099760 -0.842671
# ...         ...       ...       ...       ...       ...       ...       ...
# 53915 -1.050466 -0.809805  1.524769 -1.245589 -0.244055  0.690695 -0.873770
# 53916 -0.776075  0.085776 -0.238608  1.790204 -1.012041  0.243081 -0.668865
# 53917 -0.586113  0.981357  0.349185  1.183045  0.174846 -1.099760 -0.442141
# 53918  0.025990  0.085776 -0.238608 -0.031272  0.174846  0.243081 -0.234979
# 53919 -0.206187 -1.705387 -0.826400 -0.638430  2.548620  0.690695 -0.524404
#
#               x         y         z    volume
# 0     -1.332502 -1.316895 -1.314897 -1.075035
# 1     -0.939435 -0.911954 -0.924509 -0.859939
# 2      0.918700  0.896785  0.926218  0.789608
# 3     -0.885835 -0.848963 -0.751003 -0.800972
# 4     -0.966235 -0.938950 -1.083556 -0.901981
# ...         ...       ...       ...       ...
# 53915 -1.314635 -1.280900 -1.314897 -1.066236
# 53916 -0.733968 -0.776973 -0.852215 -0.775182
# 53917 -0.510634 -0.480016 -0.476286 -0.571243
# 53918  0.195099  0.167890  0.203278 -0.002330
# 53919 -0.242634 -0.192058  0.073148 -0.282572
#
# [53917 rows x 11 columns]

# %%
dataScaled.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  5.391700e+04  5.391700e+04  5.391700e+04  5.391700e+04  5.391700e+04
# mean  -1.841162e-15 -5.983018e-17  9.962912e-17  2.260105e-16  4.382631e-13
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.261536e+00 -2.600968e+00 -2.001984e+00 -1.852747e+00 -1.309036e+01
# 25%   -8.393963e-01 -8.098054e-01 -8.263999e-01 -6.384302e-01 -5.233230e-01
# 50%   -2.061870e-01  8.577595e-02 -2.386077e-01 -3.127175e-02  3.521209e-02
# 75%    5.114503e-01  9.813573e-01  9.369769e-01  5.758867e-01  5.239303e-01
# max    8.890921e+00  9.813573e-01  1.524769e+00  2.397362e+00  1.204372e+01
#
#               table         price             x             y             z  \
# count  5.391700e+04  5.391700e+04  5.391700e+04  5.391700e+04  5.391700e+04
# mean   8.914434e-15 -2.029482e-17  4.291274e-14  6.349643e-15 -8.978455e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.471125e+00 -9.041174e-01 -1.788102e+00 -1.847818e+00 -3.570471e+00
# 25%   -6.521461e-01 -7.478680e-01 -9.126348e-01 -9.119537e-01 -9.100504e-01
# 50%   -2.045324e-01 -3.837040e-01 -2.823404e-02 -2.108253e-02 -1.360442e-02
# 75%    6.906952e-01  3.491383e-01  7.221666e-01  7.258094e-01  7.237946e-01
# max    1.680479e+01  3.734960e+00  4.474170e+00  4.325289e+00  4.974683e+00
#
#              volume
# count  5.391700e+04
# mean   2.223429e-14
# std    1.000000e+00
# min   -1.283113e+00
# 25%   -8.451750e-01
# 50%   -1.957124e-01
# 75%    5.368483e-01
# max    8.637380e+00

# %%
hist = dataScaled.hist(figsize = (25,25), bins=100)
